# %% [markdown]
# ## NCAA March Madness Prediction (Pt. 2)

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Part 1: Importing Clean Teams Data

# %%
cleaned_teams = pd.read_csv("data/cleaned_teams.csv")
print(cleaned_teams.columns) 
cleaned_teams.head()
# Out:
# Index(['School', 'W', 'L', 'SRS', 'SOS', 'W.1', 'L.1', 'W.2', 'L.2', 'W.3',
#        'L.3', 'Tm.', 'Opp.', 'MP', 'FG', 'FGA', '3P', '3PA', 'FT', 'FTA',
#        'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'Opp_FG', 'Opp_FGA',
#        'Opp_3P', 'Opp_3PA', 'Opp_FT', 'Opp_FTA', 'Opp_ORB', 'Opp_TRB',
#        'Opp_AST', 'Opp_STL', 'Opp_BLK', 'Opp_TOV', 'Opp_PF', 'Pace', 'ORtg',
#        'FTr', '3PAr', 'TS%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'eFG%', 'TOV%',
#        'ORB%', 'FT/FGA', 'Opp_Pace', 'Opp_ORtg', 'Opp_FTr', 'Opp_3PAr',
#        'Opp_TS%', 'Opp_TRB%', 'Opp_AST%', 'Opp_STL%', 'Opp_BLK%', 'Opp_eFG%',
#        'Opp_TOV%', 'Opp_ORB%', 'Opp_FT/FGA'],
#       dtype='object')
#               School   W   L    SRS    SOS  W.1  L.1  W.2  L.2  W.3  \
# 0  Abilene Christian  27   7  -1.91  -7.34   14    4   13    2   10
# 1      Arizona State  23  11  10.28   6.04   12    6   13    3    6
# 2             Auburn  30  10  20.84  10.92   11    7   15    2    4
# ...

# %% [markdown]
# #### Part 2: Importing Game Data

# %%
game_data = pd.read_csv("data/games.csv", dtype={'w_l': str})
print(game_data.shape)
print(game_data.columns)
game_data.head()
# Out:
# (90968, 40)
# Index(['team_name', 'game_num', 'date', 'site', 'opp_name', 'w_l', 'pts',
#        'opp_pts', 'fg', 'fga', 'fg_per', '3p', '3pa', '3p_per', 'ft', 'fta',
#        'ft_per', 'orb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'opp_fg',
#        'opp_fga', 'opp_fg_per', 'opp_3p', 'opp_3pa', 'opp_3p_per', 'opp_ft',
#        'opp_fta', 'opp_ft_per', 'opp_orb', 'opp_trb', 'opp_ast', 'opp_stl',
#        'opp_blk', 'opp_tov', 'opp_pf'],
#       dtype='object')
#                     team_name  game_num        date  site         opp_name  \
# 0  Abilene Christian Wildcats         1  2013-11-09  Away         Duquesne
# 1  Abilene Christian Wildcats         2  2013-11-11  Away  St. Bonaventure
# 2  Abilene Christian Wildcats         3  2013-11-13  Away         Maryland
# 3  Abilene Christian Wildcats         4  2013-11-17  Away             Iowa
# 4  Abilene Christian Wildcats         5  2013-11-19  Away              TCU
#
# ...
